# %%
import numpy as np
import operator

# %%
import csv
import networkx as nx
import matplotlib.pyplot as plt

graph = {}

G = None
G=nx.Graph()

with open('casts.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=';', quotechar='"')
    
    for row in reader:
        if row[1] is not "" and row[2] is not "" and row[1] != "s a" and row[2] != "s a": 
            movie = row[1]

            #because csv in sorted according name of film
            if movie not in graph:
                graph[movie] = set()

            graph[movie].add(row[2]) # add actor

# %%
for movie in graph:
    for actor1 in graph[movie]:
        for actor2 in graph[movie]:
            if (actor1 is not actor2):
                G.add_edge(actor1, actor2)

# %%
# plt.figure(figsize=(20,10))
# pos = nx.spring_layout(G)
# nx.draw(G, pos,
#         labels={v:str(v) for v in G},
#         cmap = plt.get_cmap("bwr"),
#         node_color=[G.degree(v) for v in G],
#         font_size=12
#        )
# plt.show()

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 16281
# Number of edges: 152266
# Average degree:  18.7047

# %%
nx.density(G)
# Out:
# 0.0011489402865853943

# %%
nx.number_of_nodes(G)
# Out:
# 16281

# %%
sorted(nx.degree_centrality(G).items(), key=lambda x:x[1],reverse=True)[:10]
# Out:
# [('Humphrey Bogart', 0.02635135135135135),
#  ('James Stewart', 0.02291154791154791),
#  ('Gary Cooper', 0.022665847665847665),
#  ('John Gielgud', 0.022665847665847665),
#  ('John Carradine', 0.02248157248157248),
#  ('Peter Lorre', 0.022051597051597052),
#  ('C.Aubrey Smith', 0.020638820638820637),
#  ('Henry Fonda', 0.01984029484029484),
#  ('Burt Lancaster', 0.019103194103194103),
#  ('Basil Rathbone', 0.01898034398034398)]

# %%
communities = nx.clustering(G)

# %%
communities
# Out:
# {'Jane greer': 1.0,
#  'Goetz Otto': 1.0,
#  'Georgina Hale': 1.0,
#  'Tony Vilar': 0.0,
#  'Stefania Casini': 0.5238095238095238,
#  'Cathy Motiarty': 1.0,
#  'Deborah Rush': 1.0,
#  'Jim Abbott': 1.0,
#  'Judith Evelyn': 0.41,
#  'A.B. Imenson': 1.0,
#  'William E. Shay': 1.0,
#  'Steve Geray': 0.22072072072072071,
#  'Richard Shull': 1.0,
#  'Canmpell Scott': 1.0,
#  'Daniel Roebuck': 1.0,
#  'Bill C': 1.0,
#  'Lila Lee': 0.3954022988505747,
#  'Lucia Zanussi': 1.0,
#  'Frederick Piper': 0.72,
#  'Jason Miller': 0.27205882352941174,
#  'Dewey Martin': 1.0,
#  'Ken Wahl': 0.1695906432748538,
#  'Art Metrano': 0.3787878787878788,
#  'Toni Plana': 1.0,
#  'Fritz Leiber': 0.34061458718992965,
#  'William Windom': 0.18285714285714286,
#  'Sydney Arnold': 1.0,
#  'Keith Baxter': 0.6060606060606061,
#  'Gunther Kieslich': 0.0,
#  'Richard Arlen': 0.2483130904183536,
#  'Buddy Baer': 0.6257309941520468,
#  'Sharon Stone': 0.1451360650609947,
#  'Gene Roth': 1.0,
#  'Mary Miles': 1.0,
#  'Warren Cosell': 1.0,
#  'Cindy Morgan': 1.0,
#  'Jules Dassin': 0.4696969696969697,
#  'Allan Baxter': 1.0,
#  'Harry Andrews': 0.13374344953292322,
#  'Joe Dallesandro': 0.35714285714285715,
#  'Bruno V. Seta': 1.0,
#  'Elizabeth Rush': 0.0,
#  'Pal': 0.9111111111111111,
#  'Dana Delaney': 0.20333333333333334,
#  'Michele Breton': 1.0,
#  'Sophie Marceau': 0.49538461538461537,
#  'Helen Shaver': 0.3333333333333333,
#  'Robert Webber': 0.13386138613861387,
#  'Dorothy Tristan': 0.5303030303030303,
#  'Lamberto Maggiorani': 0.0,
#  'Kennan Wynn': 1.0,
#  'Jaime Sanchez': 1.0,
#  'Joe Torry': 1.0,
#  'Maiwenn leBesio': 1.0,
#  'Enid Thompson': 1.0,
#  'Tim Allen': 0.6666666666666666,
#  'Theodore Roosevelt': 1.0,
#  'Annette Funicello': 0.30808080808080807,
#  'Hedy Lamarr': 0.28374455732946297,
#  'Henny Youngman': 1.0,
#  'Raymond Bailey': 1.0,
#  'Adolph Ceasar': 0.7142857142857143,
#  'Gertrude Messenger': 1.0,
#  'Christopher Lee': 0.07221502590673576,
#  'Sara Kestelman': 0.6111111111111112,
#  'Tara Reid': 1.0,
#  'Dennis Quilley': 1.0,
#  'percy Kilbride': 1.0,
#  'Eric Bruskotter': 1.0,
#  'Barry Kelley': 1.0,
#  'Ralph Schicha': 0.0,
#  'Pat Paterson': 1.0,
#  'Alan Hewitt': 0.3939393939393939,
#  'Stegan Glowacz': 1.0,
#  'Robert Montgomery': 0.1341991341991342,
#  'Michael Rennie': 0.125,
#  'Alan Marshal': 0.3894736842105263,
#  'David Horne': 0.4166666666666667,
#  'Deborah vanFalkenburgh': 1.0,
#  'William Devane': 0.19692307692307692,
#  'Joe Spano': 0.4857142857142857,
#  'Jill Townsend': 0.4,
#  'Mary Carr': 0.5220588235294118,
#  'Rufus Read': 1.0,
#  'Ed Nelson': 0.2413793103448276,
#  'Connie Russell': 1.0,
#  'Hugh Grant': 0.13193473193473193,
#  'David Rappaport': 1.0,
#  'Richard Conte': 0.12687312687312688,
#  'Ernest Hardee': 1.0,
#  'Noel Drayton': 1.0,
#  'Salvador Dali': 1.0,
#  'Ron Livingston': 1.0,
#  'Whip Hutley': 1.0,
#  'Joe Grifasi': 0.3416666666666667,
#  'Wilfrid Brambell': 1.0,
#  'Jose Sacristan': 1.0,
#  'Ke Huy Kwan': 1.0,
#  'Gloria Gifford': 0.4789473684210526,
#  'Helen Miren': 0.0,
#  'Norman Bristow': 1.0,
#  'Cathianne Blore': 1.0,
#  'Phyllis Konstam': 0.5,
#  'Gunnar Bowman': 1.0,
#  'Purnendu Mukherjee': 1.0,
#  'Kenneth More': 1.0,
#  'John Anderson': 0.48412698412698413,
#  'Phylllis Haver': 0.0,
#  'Lisa Croisette': 1.0,
#  'Shelly Winters': 1.0,
#  'Ian Anderson': 1.0,
#  'Jenifer Lewis': 1.0,
#  'Vanda Godsell': 1.0,
#  'Tony Basil': 1.0,
#  'David Zucker': 0.7233333333333334,
#  'Lorraine Pilkinton': 1.0,
#  'Warrem Hymer': 1.0,
#  'Russel Streiner': 1.0,
#  'Judy Bowker': 1.0,
#  'Jean Rogers': 0.55,
#  'Liam Neeson': 0.09085213032581453,
#  'Michael Chekhov': 1.0,
#  'Lotus Weinstock': 1.0,
#  'Alan S. Craig': 1.0,
#  'Krystyna Janda': 0.3333333333333333,
#  'George Lewis': 1.0,
#  'Cassius Clay': 1.0,
#  'Richard Jordan': 0.16832261835184104,
#  'Anne Shirley': 0.2303422756706753,
#  'John Bell': 1.0,
#  'Ava Gardner': 0.09847494553376906,
#  'Tony Martin': 0.18235294117647058,
#  'Rory Calhoun': 0.29411764705882354,
#  'Zoe Yuzna': 1.0,
#  'Margaret lockwood': 1.0,
#  'Roy Thinnes': 1.0,
#  'Michael Bien': 1.0,
#  'Zvee Scooler': 1.0,
#  'Fay Compton': 0.17295873573309922,
#  'Wendy Hiller': 0.12827393731215114,
#  'Claude Jarman jr': 1.0,
#  'Elsie Ferguson': 1.0,
#  'Dooley Wilson': 0.36363636363636365,
#  'Ingrid Thulin': 0.3442028985507246,
#  'Betta StJohn': 1.0,
#  'Felix Aymer': 1.0,
#  'Tommy Steele': 0.3216374269005848,
#  'Cherry McClain': 1.0,
#  'Placido Domingo': 0.6911764705882353,
#  'Kathleen Klemont': 1.0,
#  'Barbara LeighHunt': 1.0,
#  'Vanessa xx': 1.0,
#  'Simone Signoret': 0.27906976744186046,
#  'Nathalie Baye': 0.3548387096774194,
#  'LisaMarle Felter': 1.0,
#  'Anne Meara': 0.2605042016806723,
#  'Russell Wong': 0.4857142857142857,
#  'Stuart Pankin': 1.0,
#  'Rade Serbedzija': 1.0,
#  'Beverly Washburn': 1.0,
#  'Mechtild Grossman': 0.0,
#  'Christine Noonan': 1.0,
#  'William Bowers': 1.0,
#  'Art Aragon': 1.0,
#  'James Craig': 0.26136363636363635,
#  'Charmian Carr': 1.0,
#  'Anne revere': 1.0,
#  'David Birney': 1.0,
#  'Edna Doré': 1.0,
#  'Katherine Houghton': 1.0,
#  'Alejandro Rey': 0.24175824175824176,
#  'Ingrid Pitt': 0.41025641025641024,
#  'John Dierkes': 0.26461538461538464,
#  'Joyce Bland': 1.0,
#  'Helen Chandler': 0.5285285285285285,
#  'Harve Presnell': 0.5151515151515151,
#  'Noel Neill': 0.5666666666666667,
#  'Brenda Vaccaro': 0.20229885057471264,
#  'Allison Jones': 1.0,
#  'Lemmy Caution': 1.0,
#  'Monroe Salisbury': 1.0,
#  'Nicholas Brothers': 1.0,
#  'Lucien Lttlefield': 1.0,
#  'Max Born': 1.0,
#  'Hawthorne James': 1.0,
#  'René Creste': 1.0,
#  'Gajendra': 1.0,
#  'Eric Schweig': 1.0,
#  'MarieChristine Barrault': 0.18947368421052632,
#  'Peter Lorre': 0.07016697530383903,
#  'Wanda McKay': 1.0,
#  'Ekrem Bora': 1.0,
#  'Christine Kaufmann': 1.0,
#  'Richard Edson': 0.7362637362637363,
#  'Richard Brok': 1.0,
#  'Maxine Audley': 0.28378378378378377,
#  'Sonja Henie': 0.6111111111111112,
#  'Al dAmato': 1.0,
#  'Marjane': 1.0,
#  'Gabriella Licudi': 0.38596491228070173,
#  'Michael Craig': 0.3660130718954248,
#  'Udo Samel': 1.0,
#  'Helen Conrad': 1.0,
#  'Jean-Louis Trintignant': 1.0,
#  'Arthur Margetson': 0.49122807017543857,
#  'Susan Damante Shaw': 0.6,
#  'Caprice Toriel': 1.0,
#  'Philip Delambre': 1.0,
#  'Julian Jenkins': 1.0,
#  'Vesa Vierikko': 1.0,
#  'Robby Benson': 0.20689655172413793,
#  'David Knell': 1.0,
#  'Deborah May': 1.0,
#  'Jacques Duby': 1.0,
#  'Judy Geeson': 0.3014705882352941,
#  'Elisa Giani': 1.0,
#  'Leonard Mudie': 0.4089795918367347,
#  'Jason Robards jr.': 0.1251366120218579,
#  'Adrienne Bobes': 1.0,
#  'Cassandra Harris': 1.0,
#  'Lonette McKee': 0.20855614973262032,
#  'Charles Killman': 1.0,
#  'Richard Easton': 1.0,
#  'Judith Ivey': 0.5272727272727272,
#  'Nancy Welford': 1.0,
#  'Paul Danwuah': 1.0,
#  'James Gondolfina': 1.0,
#  'Matthew McConnaghey': 1.0,
#  'Carl Schenstrom': 1.0,
#  'Isobel Elsom': 0.15443745632424877,
#  'Peter Newman': 1.0,
#  'LeslieAnn Doen': 1.0,
#  'Ron Rifkin': 0.3076923076923077,
#  'Ian Richardson': 0.4920212765957447,
#  'Lionel Stander': 0.10537790697674419,
#  'Rosamund John': 1.0,
#  'Juan Jose Gurrola': 0.0,
#  'Raynor Scheine': 1.0,
#  'Ed Brophy': 0.39492753623188404,
#  'May Boley': 0.5688405797101449,
#  'Cecil B. DeMille': 1.0,
#  'Melanie Mayron': 0.19047619047619047,
#  'Vladimir Pucholt': 1.0,
#  'Cornelia Froeboess': 1.0,
#  'Steffi Dunna': 0.4928774928774929,
#  'Oscar Polk': 1.0,
#  'Grant Cramer': 1.0,
#  'Dorothy Adsams': 1.0,
#  'Badja Djola': 1.0,
#  'Walter Matthau': 0.05573868744381181,
#  'Phyllis Kirk': 1.0,
#  'Tricia ONeil': 1.0,
#  'Vittoria Gassman': 1.0,
#  'Mary Chris Wall': 1.0,
#  'Alan Hale jr': 0.4727272727272727,
#  'Dimitris Papamichael': 1.0,
#  'Francoise Lugagne': 1.0,
#  'S.J. Warmington': 1.0,
#  'Paul Faivre': 1.0,
#  'Catherine Frot': 1.0,
#  'Derek Godfrey': 1.0,
#  'David Warren': 1.0,
#  'Patti DArbanville': 1.0,
#  'Else Kentner': 0.0,
#  'Al Carmines': 1.0,
#  'John Lupton': 1.0,
#  'Lester Matthew': 1.0,
#  'Matthew Guiness': 1.0,
#  'Sylvia Marriott': 0.4666666666666667,
#  'John Hancock': 1.0,
#  'Michael Pate': 0.2709447415329768,
#  'Franz Sala': 1.0,
#  'Tim Thomerson': 0.26143790849673204,
#  'Gordon y': 1.0,
#  'Lisa Hartman': 0.4666666666666667,
#  'Henry Silva': 0.1251959686450168,
#  'Cameron Diaz': 0.16856060606060605,
#  'Les Tremaye': 1.0,
#  'Phillip Ober': 1.0,
#  'Tony March': 1.0,
#  'Patty Yatsutake': 1.0,
#  'Madelaine Rousset': 1.0,
#  'Bill Slack': 1.0,
#  'Aline MacMahon': 0.5151515151515151,
#  'Christina Raines': 0.7789855072463768,
#  'Sophie Okonedo': 1.0,
#  'Ellen Busteyn': 1.0,
#  'Albert Lieu': 1.0,
#  'Roy Dotrice': 1.0,
#  'Vince Vaughn': 0.5833333333333334,
#  'Tina Kellegher': 0.0,
#  'Keith Green': 1.0,
#  'Robert Henderso Bland': 1.0,
#  'Jason Patric': 0.29523809523809524,
#  'Robert Kennedy': 1.0,
#  'Leonore Aubert': 1.0,
#  'Marcia Mae': 1.0,
#  'Vsevolod Pudovkin': 0.5714285714285714,
#  'Jack Taylor': 0.0,
#  'Kerry Fox': 0.19166666666666668,
#  'Clare Binney': 1.0,
#  'Matt Moore': 0.4666666666666667,
#  'Cao Cuifen': 1.0,
#  'George Duryea': 1.0,
#  'Olin Howard': 0.48917748917748916,
#  'Walter Catlett': 0.12796420581655482,
#  'Juan DeLaCruz': 1.0,
#  'Marcia Strassman': 0.2924901185770751,
#  'Tallulah Bankhead': 0.3473684210526316,
#  'Elsa Lanchester': 0.10281517747858017,
#  'Anthony Edwards': 0.42857142857142855,
#  'Steve Reeves': 0.17777777777777778,
#  'Donald Cook': 0.36576168929110103,
#  'Giacomo RossiStuart': 0.6666666666666666,
#  'Joe Spinell': 1.0,
#  'Anthony Quinn': 0.06297173301761137,
#  'Claire Trevor': 0.1450827653359299,
#  'Jorgen Reenberg': 1.0,
#  'Don Phillip xx': 1.0,
#  'Mark Malone': 1.0,
#  'Swoosie Kurtz': 0.24242424242424243,
#  'Ashley Ohara': 1.0,
#  'Dennis Moore': 1.0,
#  'Brian Dehenny': 0.4444444444444444,
#  'Murray Melvin': 0.5384615384615384,
#  'Jean Yanne': 0.5454545454545454,
#  'Ben Bernie': 0.6190476190476191,
#  'Royal Beal West': 1.0,
#  'Sam Neil': 0.36615384615384616,
#  'William Hopper': 1.0,
#  'Jonah Blechman': 1.0,
#  'Cecil Kellaway': 0.10427163198247535,
#  'Paul McCartney': 0.7714285714285715,
#  'Grant Page': 0.0,
#  'Ann Carter': 1.0,
#  'Mark Blum': 0.5333333333333333,
#  'Sir Thomas Beecham': 1.0,
#  'Mahalia Jackson': 0.475,
#  'Salome Jens': 0.4909090909090909,
#  'Yoshiko Tanaka': 1.0,
#  'Leslie Neilson': 1.0,
#  'Herve Villechaize': 0.37549407114624506,
#  'Lois Chiles': 0.22880371660859466,
#  'Howard Hill': 1.0,
#  'Perry King': 0.4621212121212121,
#  'Glenn Corbett': 0.35333333333333333,
#  'Stephen Dunne': 1.0,
#  'Harry Shannon': 0.28403361344537814,
#  'Fernanda Montenegro': 0.0,
#  'Flora Sheffield': 1.0,
#  'Peggy Lee': 0.3157894736842105,
#  'Sibham McKenna': 1.0,
#  'Lynn Bari': 0.2563265306122449,
#  'David Warner': 0.0859504132231405,
#  'Lyn Harding': 1.0,
#  'Elspeth March': 0.4666666666666667,
#  'Dominic Guard': 0.75,
#  'Estelle Taylor': 0.56006006006006,
#  'Annabelle Sciorra': 0.5,
#  'Richard Castellano': 0.6608187134502924,
#  'Ivo Garrani': 1.0,
#  'Drew Michaels': 1.0,
#  'John Masrley': 0.0,
#  'John Macurdy': 1.0,
#  'Cary Elwes': 0.1525478740668614,
#  'Bolek Polivka': 1.0,
#  'Elena Safonova': 1.0,
#  'Tracy Camilla Johns': 0.4722222222222222,
#  'Rusty Lane': 0.2948717948717949,
#  'Johnson Mountain Boys': 0.0,
#  'Evelyn Rude': 1.0,
#  'Penelope Anne Miller': 0.5636363636363636,
#  'Bette Davis': 0.07620117109168204,
#  'Moritz Bleibtreu': 1.0,
#  'Catherine Schell': 0.8306451612903226,
#  'Jacques Dutronc': 0.3333333333333333,
#  'Maxine Lapiduss': 1.0,
#  'Ruth White': 0.5661764705882353,
#  'Antonio Moreno': 0.23384615384615384,
#  'Jacqueline Pearce': 0.5909090909090909,
#  'Judy Garland': 0.14157014157014158,
#  'Nick E.': 1.0,
#  'Max vonBulow': 1.0,
#  'Martingale': 1.0,
#  'Hoyt Aston': 1.0,
#  'Clifton Davis': 1.0,
#  'Anthony Dowall': 1.0,
#  'Dean Jagger': 0.0945193171608266,
#  'Angeline Ball': 1.0,
#  'Rolla France': 1.0,
#  'Timothy Hutton': 0.17692307692307693,
#  'Julanna Johnston': 1.0,
#  'Isabella Celani': 1.0,
#  'Debbie James': 1.0,
#  'Greg Kinneaer': 1.0,
#  'Lu Man San': 1.0,
#  'Paul McAllister': 1.0,
#  'Charles Kemper': 1.0,
#  'Amelia Bullmore': 1.0,
#  'Monique Dury': 1.0,
#  'John Ellison': 1.0,
#  'Roger Rees': 0.4444444444444444,
#  'Bobby deCico': 1.0,
#  'Marcia Mae Jones': 0.39886039886039887,
#  'Peter Bull': 0.17037037037037037,
#  'Basil Sydney': 1.0,
#  'Magnus Härenstam': 1.0,
#  'Luis VanRooten': 1.0,
#  'James Fox': 0.10566037735849057,
#  'Nelson Eddy': 0.23585434173669467,
#  'Russ Barry': 1.0,
#  'Fuzzy Knight': 0.47619047619047616,
#  'Henry Fonda': 0.06911139741937965,
#  'Clarence Nordstrom': 1.0,
#  'Milan Maric': 1.0,
#  'Jason Robards': 0.0611646418098031,
#  'Patricia Wettig': 0.4222222222222222,
#  'Paula Raymond': 0.2753623188405797,
#  'Dean Williams': 1.0,
#  'Michelle Pfeiffer': 0.06802721088435375,
#  'George Graves': 1.0,
#  'Dennis ODay': 0.5324675324675324,
#  'Moray Watson': 1.0,
#  'Bert Roach': 0.21993911719939116,
#  'Annette Kellerman': 1.0,
#  'Cort Hubbert': 1.0,
#  'Cynthia Sikes': 1.0,
#  'Dick York': 0.1497584541062802,
#  'Karen Gorney': 1.0,
#  'Zack Norman': 1.0,
#  'Jennifer Ashley': 0.7333333333333333,
#  'Eugene Palette': 0.3333333333333333,
#  'De Laete': 1.0,
#  'Hans Conried': 0.1398198198198198,
#  'Donna Corcoran': 0.4189723320158103,
#  'Devon Raymond': 1.0,
#  'George Harrison': 0.7714285714285715,
#  'Charlie Ruggles': 0.44761904761904764,
#  'Goldie Hawn': 0.08551641071966275,
#  'Garcelle Beauvais': 1.0,
#  'Leonard Strong': 0.5909090909090909,
#  'Alexander Godonov': 1.0,
#  'Natasha Gregson Warner': 1.0,
#  'Martha ODiriscoll': 1.0,
#  'Paul Langton': 1.0,
#  'Maggie Jacobson': 1.0,
#  'David McCallum': 0.18797953964194372,
#  'Kim McGuire': 1.0,
#  'Marilyn Monroe': 0.09311180339217723,
#  'Kathleen Quinlan': 0.12268640930724485,
#  'Art Acord': 1.0,
#  'Tom Adams': 1.0,
#  'Gerard Darmon': 1.0,
#  'Nicoletta Braschi': 1.0,
#  'Meg Dotrice': 1.0,
#  'Charles Boyer': 0.1169608543345917,
#  'Jean Rouverol': 1.0,
#  'Laird Cregar': 0.18036529680365296,
#  'Teri Polo': 0.5926829268292683,
#  'Constance Garneau': 1.0,
#  'John Marshall Jones': 1.0,
#  'John Rubenstein': 1.0,
#  'Jimmy "The Greek" Snyder': 1.0,
#  'Mary Elizabeth Mastroianni': 1.0,
#  'Gwen Frangcon Davies': 1.0,
#  'George DiSend': 1.0,
#  'Doug Cooeyate': 1.0,
#  'John Tetzel': 1.0,
#  'Johnny Crawford': 1.0,
#  'Gene Raymon': 1.0,
#  'Hope Lange': 0.2222222222222222,
#  'George Touliatos': 1.0,
#  'Sacha Guitry': 0.3473684210526316,
#  'Laila Morse': 1.0,
#  'Jan Sterling': 0.1996996996996997,
#  'Julie Hendriksen': 1.0,
#  'Gary Raymond': 0.22916666666666666,
#  'Robert Stephens': 0.3091772151898734,
#  'Bobby Ellis': 1.0,
#  'Ann Richards': 0.29590017825311943,
#  'Claire Bloom': 0.1312785388127854,
#  'Mary Maya': 1.0,
#  'Elaine Strich': 1.0,
#  'Ornella Mutti': 0.675,
#  'Nyree Dawn Porter': 1.0,
#  'Alan Bates': 0.2111644932509723,
#  'Diana Sands': 0.5054945054945055,
#  'Billy Gray': 0.3956043956043956,
#  'John Loder': 0.13583021223470662,
#  'Edward Conrad': 1.0,
#  'Kathryn McNeil': 0.0,
#  'Philip Michael Thomas': 1.0,
#  'Dan Dailey': 0.2712765957446808,
#  'Ricky Lake': 1.0,
#  'Bill Hunter': 0.23529411764705882,
#  'Rudolph Velentino': 1.0,
#  'Anna Pacquin': 0.48717948717948717,
#  'Joseph Grehan': 1.0,
#  'Anthony Dawson': 0.25249169435215946,
#  'Branford Marsalis': 1.0,
#  'Donald pleasence': 1.0,
#  'Anna May Wong': 0.1623529411764706,
#  'Linda Shaw': 1.0,
#  'Megan Ward': 0.46153846153846156,
#  'Michael Berryman': 0.5714285714285714,
#  'Andre Wilms': 0.4444444444444444,
#  'Leslie Parrish': 0.6444444444444445,
#  'Mikki Allen': 1.0,
#  'Eric Rohmer': 1.0,
#  'Leo Camillo': 1.0,
#  'J.Barney Sherry': 0.3111111111111111,
#  'Pia Zadora': 0.3743078626799557,
#  'Lilyan Tashman': 0.19346938775510203,
#  'Dmitri Orlov': 1.0,
#  'Kevin lin': 1.0,
#  'Ewen Bremner': 1.0,
#  'Esther Howard': 0.3226890756302521,
#  'Lesley Ann Warren': 0.5375494071146245,
#  'Tasuya Nkadai': 0.0,
#  'William Sadler': 1.0,
#  'Michael McClanathan': 1.0,
#  'Carlos Rivas': 1.0,
#  'Glen Tryon': 1.0,
#  'Conchata Ferrell': 1.0,
#  'Ron Bain': 1.0,
#  'Rowena King': 1.0,
#  'Jimmy Karoubi': 1.0,
#  'Richard Wattis': 0.2573170731707317,
#  'John Laughlin': 1.0,
#  'Carry Fisher': 1.0,
#  'Victor Killian': 0.3793103448275862,
#  'Lena Heady': 1.0,
#  'Susan Beggs': 1.0,
#  'J.G. Hertzler': 1.0,
#  'Fred Travalena': 1.0,
#  'David Janti': 1.0,
#  'Dan Daily': 1.0,
#  'Kaki Hunter': 0.4,
#  'Robert MacNaughton': 1.0,
#  'Lupino Lane': 1.0,
#  'Monty Wooly': 1.0,
#  'Greg Cruttwell': 1.0,
#  'June Brown': 1.0,
#  'Dale Miki': 1.0,
#  'Jeff Chandler': 0.304421768707483,
#  'Lee Strasberg': 0.3842364532019704,
#  'Angela Moya': 1.0,
#  'Cecile Aubry': 0.0,
#  'Frédéric VanDenDriesche': 1.0,
#  'Robert Warwick': 0.24477611940298508,
#  'Gene Krupa': 0.22795115332428764,
#  'Roger Corman': 0.47186147186147187,
#  'Anna Perrier': 1.0,
#  'Helen Dunbar': 1.0,
#  'Hart Bochner': 0.3144284454892742,
#  'Ellen Corby': 0.27058823529411763,
#  'Lesley Manville': 1.0,
#  "`Ellay Morte'": 0.0,
#  'Vivian Pickles': 1.0,
#  'William Hickey': 0.3508771929824561,
#  'Howard Cosell': 1.0,
#  'Byron Foulger': 1.0,
#  'Roscoe Kearns': 1.0,
#  'Arnold Moss': 0.3201581027667984,
#  'Patricia Ellis': 0.6535947712418301,
#  'Jaqueline Susann': 1.0,
#  'Philip Ahn': 0.33048433048433046,
#  'Jill Balcon': 1.0,
#  'Evelyn Ankers': 0.18531073446327684,
#  'Kathryn Bard': 1.0,
#  'Teddy Wison': 1.0,
#  'David Krumholtz': 1.0,
#  'John Turtorro': 0.3333333333333333,
#  'Victoria Russell': 1.0,
#  'Kit Taylor': 1.0,
#  'Chris Penn': 0.4,
#  'Harry Fowler': 1.0,
#  'Hugo Haas': 0.3741935483870968,
#  'Ron Hayes': 1.0,
#  'James Wainwright': 0.5128205128205128,
#  'Nora Dawn': 1.0,
#  'robert Stack': 1.0,
#  'Rita Tushinham': 1.0,
#  'Susie Porter': 1.0,
#  'James Finlayson': 0.25359911406423036,
#  'Richard Basehart': 0.17669172932330826,
#  'Russ Brown': 1.0,
#  'Fred Niblo': 1.0,
#  'Jules Bledsoe': 1.0,
#  'Darlanne Fluegel': 0.25675675675675674,
#  'Reta Shaw': 0.33986928104575165,
#  'Ronnie Hawkins': 1.0,
#  'John Alderson': 1.0,
#  'Brigitte Lahaie': 1.0,
#  'Marjorie Daw': 0.3333333333333333,
#  'Ricard Murdoch': 1.0,
#  'Al Martino': 0.5887096774193549,
#  'Cynthia Nixon': 0.35333333333333333,
#  'Carol Heiss': 1.0,
#  'Christopher Eccleston': 0.5,
#  'Jill Livesey': 1.0,
#  'Pavel Kadochnikov': 1.0,
#  'Jay Silverheels': 0.4155844155844156,
#  'Bruce Greenwood': 0.4642857142857143,
#  'Lesley-Ann Down': 0.9047619047619048,
#  'Sabrina Scharf': 0.7941176470588235,
#  'Bryan Kevin': 1.0,
#  'Warwick Buckland': 1.0,
#  'Paule Picerni': 1.0,
#  'Gina Gershon': 0.3626373626373626,
#  'Lois Maxwell': 0.10912343470483005,
#  'Ilona Massey': 1.0,
#  'Barry Robin': 1.0,
#  'Alice Nunn': 1.0,
#  'Wade Boteler': 1.0,
#  'Valerie Perrine': 0.2460881934566145,
#  'Barry Dennen': 1.0,
#  'Peter Sellers Colman': 1.0,
#  'Margaret Rurtherford': 1.0,
#  'Donatas Banionis': 1.0,
#  'Brian Murray': 1.0,
#  'Marcel Vibert': 1.0,
#  'Kelly Preston': 0.24183006535947713,
#  'Charles Tingwell': 0.4444444444444444,
#  'Edgar Norton': 0.28653061224489795,
#  'Alan badel': 1.0,
#  'Dorothy Alison': 0.48484848484848486,
#  'Hans vonSchlettow': 1.0,
#  'Sarah Bay': 1.0,
#  'Glynn Thurman': 1.0,
#  'Nina vanPallandt': 1.0,
#  'Jon Voigt': 1.0,
#  'Don Dubbins': 0.4642857142857143,
#  'Sidney Franklin': 1.0,
#  'Helen Stanton': 0.42857142857142855,
#  'Gastone Renzelli': 1.0,
#  'Steve Gerat': 1.0,
#  'Don Defoe': 0.5256410256410257,
#  'Otto Sander': 0.4624505928853755,
#  'Dan Martin': 0.696969696969697,
#  'Olgierd Lukaszewicz': 0.0,
#  'Lela Rogers': 1.0,
#  'Veronica Ladd': 1.0,
#  'Cyril Ring': 1.0,
#  'Bransby Williams': 1.0,
#  'David King Wood': 1.0,
#  'Yacef Saadi': 1.0,
#  'Liv Tyler': 0.2676923076923077,
#  'Frank Latimore': 0.5071225071225072,
#  'Jennifer Bishop': 1.0,
#  'Elizabeth Perkins': 0.221505376344086,
#  'Dita Parlo': 0.5769230769230769,
#  'Nathalie Nell': 1.0,
#  'Tim Henry': 1.0,
#  'Pierre Batcheff': 0.5238095238095238,
#  'Henry Daniel': 1.0,
#  'Crissy Rock': 0.0,
#  'Bruce Spence': 1.0,
#  'Roberto Benigngi': 0.0,
#  'Jeff Bridges': 0.05793255942509674,
#  'Ann Magnusson': 1.0,
#  'Richard Gering': 0.4666666666666667,
#  'Logan Ramsey': 1.0,
#  'Brynja McGrady': 1.0,
#  'Jerry Austin': 0.543859649122807,
#  'Francis Dade': 1.0,
#  'Nallig Horrigan': 1.0,
#  'Ray Middleton': 1.0,
#  'Katerina Witt': 1.0,
#  'Elizabeth Bracco': 0.5573122529644269,
#  'Ady Berber': 1.0,
#  'Ryan Phillipe': 1.0,
#  'Larry Riley': 1.0,
#  'Ann Poirot': 1.0,
#  'Linda Blair': 0.35177865612648224,
#  'Bob Arthur': 0.5,
#  'Jinx Falkenburg': 1.0,
#  'Fay Hemlm': 1.0,
#  'Jim Antonio': 1.0,
#  'Pierre Trabaud': 1.0,
#  'Rufus Sewell': 0.14532019704433496,
#  'Robert coote': 1.0,
#  'Maximiliam Schell': 1.0,
#  'Jimmy Edwards': 0.5494505494505495,
#  'Tom Brfown': 1.0,
#  'Lisa Kudrow': 0.37362637362637363,
#  'x Hagen': 1.0,
#  'Herman Bing': 0.3089430894308943,
#  'Robert Helpmann': 0.26737967914438504,
#  'Norah Baring': 1.0,
#  'Lido Manetti': 1.0,
#  'Laurette Spang': 1.0,
#  'Kim Novak': 0.12149532710280374,
#  'Emory Johnson': 1.0,
#  'Henry Winkler': 0.6631578947368421,
#  'William Sharon': 1.0,
#  'Judy Kelly': 0.5761904761904761,
#  'Tessa Richarde': 1.0,
#  'Iris Meredith': 1.0,
#  'Luca deFillipo': 0.0,
#  'Frederick Church': 1.0,
#  'Dudley Remus': 1.0,
#  'Stacy Harris': 1.0,
#  'Charles Peel': 1.0,
#  'Henry Kendall': 1.0,
#  'Ralph Brown': 0.31,
#  'Laura Gamser': 0.0,
#  'Miriam Goldschmidt': 1.0,
#  'Leslie Nielsen': 0.1042082350807183,
#  'Lucilla Morlacchi': 1.0,
#  'Robert Downey jr.': 0.3382352941176471,
#  'Ricky Tomlinson': 0.3333333333333333,
#  'Dany Carrell': 1.0,
#  'Richard Grant': 1.0,
#  'Shakira Caine': 1.0,
#  'Isabel Jewell': 0.22067363530778164,
#  'Roman Bohnen': 0.2595918367346939,
#  'Ketti Gallian': 0.5641025641025641,
#  'Tom Skerrit': 1.0,
#  'Jack Shepperd': 1.0,
#  'Roissy de Palma': 1.0,
#  'Esther Muir': 1.0,
#  'Peggy Sawyer': 1.0,
#  'Philip DForn': 1.0,
#  'Lorne Greene': 0.35294117647058826,
#  'Lola Falana': 1.0,
#  'Maria Mercader': 1.0,
#  'Edward Furlong': 0.1978021978021978,
#  'Christiane Mays': 1.0,
#  'Arturo Pirovani': 0.0,
#  'Louise Latham': 0.6111111111111112,
#  'Lumi Cavazos': 1.0,
#  'Guiliano Gemma': 1.0,
#  'Jack Lord': 0.5194805194805194,
#  'Walter Tony Huston': 1.0,
#  'Lutze Hagen': 1.0,
#  'Mary Anderson': 0.33157894736842103,
#  'MajBritt Nilsson': 0.5714285714285714,
#  'Dorotjy Malone': 1.0,
#  'Amanda Wyss': 0.4444444444444444,
#  'Marcelino Sanchez': 1.0,
#  'Jack Oakie': 0.11754692675745307,
#  'Charlie Dale': 1.0,
#  'Fannie Bryce': 1.0,
#  'Rochelle Hudson': 0.2461038961038961,
#  'Sam Peckinpah': 1.0,
#  'William Squire': 1.0,
#  'William Bergen': 1.0,
#  'Morgan Freeman?': 1.0,
#  'Michael Sarrazin': 0.15384615384615385,
#  'Joseph Kroner': 1.0,
#  'Jimmi Harkishin': 1.0,
#  'William Russell': 0.0,
#  'Bob Steele': 0.34901960784313724,
#  'Claude Allester': 1.0,
#  'Pamela Bryant': 1.0,
#  'Ricard Haydn': 1.0,
#  'Allan Jenkins': 0.40350877192982454,
#  'Maria Charles': 1.0,
#  'Laila Robbins': 1.0,
#  'Robert Woolsey': 0.6,
#  'Patrice Townsend': 1.0,
#  'Annie Golden': 1.0,
#  'Ilka Chase': 0.28342245989304815,
#  'Ralph Hoppe': 1.0,
#  'Yvonne Shima': 1.0,
#  'Pamela Duncan': 1.0,
#  'Warner Anderson': 0.40615384615384614,
#  'Dennis Hopper': 0.07187894073139975,
#  'Irene Tedrow': 1.0,
#  'Cameron English': 1.0,
#  'Joseph Schildlraut': 1.0,
#  'Ralph Macchio': 0.5714285714285714,
#  'Deborah Offner': 1.0,
#  'Douglas MacLean': 1.0,
#  'Gladys Brockwell': 0.6580645161290323,
#  'Sophie Tucker': 0.5497835497835498,
#  'Yvette Mimieux': 0.21370499419279906,
#  'Nella Montagna': 1.0,
#  'Fred McLaren': 1.0,
#  'MarieJose Nat': 1.0,
#  'Adrienne Arns': 1.0,
#  'Bonar Colleano': 1.0,
#  'Saul Bellow': 1.0,
#  'Michael Schoeffling': 0.2549019607843137,
#  'Jeffrey Nordling': 1.0,
#  'Laurence cote': 1.0,
#  'Veronica Cartwright': 0.2222222222222222,
#  'Susan Denberg': 1.0,
#  'Jimmy Conlin': 0.2309043020193152,
#  'Michael Pertwee': 1.0,
#  'Carl Laemmle': 1.0,
#  'Louise Fazenda': 0.3218390804597701,
#  'Claire Williams': 1.0,
#  'Gloria Mejia': 1.0,
#  'Andrew Duggan': 0.2948717948717949,
#  'Chisu Ryu': 0.0,
#  'Emelio Estevez': 1.0,
#  'Carl Linley': 1.0,
#  'Joe Roberts': 0.6,
#  'Gina Hecht': 1.0,
#  'Diane Wynyard': 1.0,
#  'Irene Jacob': 1.0,
#  'Jayne Modean': 1.0,
#  'Leslie French': 1.0,
#  'Gertrude Hoffman': 1.0,
#  'Elina Salo': 1.0,
#  'Joel Fluellen': 1.0,
#  'George Periolat': 1.0,
#  'Dusty Rhodes': 1.0,
#  'Eric Serra': 1.0,
#  'Fenton Terry': 1.0,
#  'Sally Geeson': 1.0,
#  'Julie Strain': 1.0,
#  'Jeffrey Tambor': 1.0,
#  'Rudolf Lucieer': 1.0,
#  'Luis Caballero': 0.0,
#  'Donald McBride': 0.15791476407914765,
#  'Mrs. Dudley Murphy': 1.0,
#  'David Spielberg': 1.0,
#  'Ina Blum': 1.0,
#  'Chris Tucker': 0.5,
#  'Bobby Darin': 0.3732193732193732,
#  'Charles Dutton': 1.0,
#  'Phillip Seymor Hoffman': 1.0,
#  'Sandrine Bonnaire': 0.2222222222222222,
#  'Rose Alba': 1.0,
#  'Elaine Benson': 1.0,
#  'Pyotr Zaichenko': 0.0,
#  'John Eldridge': 1.0,
#  'Christopher lee': 1.0,
#  'Edward Andrews': 0.1478667445938048,
#  'Melanie Griffith': 0.08337428337428338,
#  'Charlotte Granville': 1.0,
#  'Jean Adair': 1.0,
#  'Billy Milton': 1.0,
#  'Ben Asta': 1.0,
#  'Wyrly Birch': 1.0,
#  'Marjorie White': 0.5497076023391813,
#  'Peter Vaughn': 0.4025974025974026,
#  'Dennis Fimple': 1.0,
#  'Jean Hale': 1.0,
#  'Texas Starr': 1.0,
#  'John Ewart': 1.0,
#  'Matthew Boulton': 1.0,
#  'Philip Seymour Hoffman': 1.0,
#  'Georgr Zucco': 1.0,
#  'Jean Seberg': 0.2684729064039409,
#  'Sofia Coppola': 1.0,
#  'Percy Kilbride': 0.5054945054945055,
#  'Matthew Barry': 0.0,
#  'Enrico Gemelli': 1.0,
#  'Alberto Nepoti': 1.0,
#  'Paul Lukas': 0.12433079740772049,
#  'John Pankow': 0.30833333333333335,
#  'Shoba Sen': 0.0,
#  'Steve Waddington': 0.4696969696969697,
#  'Bryant Washburn': 1.0,
#  'Bill Wallace': 0.42857142857142855,
#  'Gage Clarke': 1.0,
#  'Lewis FitxGerald': 1.0,
#  'Michael Pare': 0.3888888888888889,
#  'Michel Lonsdale': 0.2777777777777778,
#  'Peter Sellers': 0.08352223190932868,
#  'Natalie Talmadge': 1.0,
#  'Julie Michael': 1.0,
#  'Michael Elphick': 1.0,
#  'Larry Maxwell': 1.0,
#  'Rodolfo Hoyos': 1.0,
#  'M. Warkles': 1.0,
#  'Maggie McNamara': 0.5636363636363636,
#  'Alexandra Stewart': 0.4857142857142857,
#  'Dermot Mulroney': 0.2028985507246377,
#  'Ada Stewart': 1.0,
#  'Nancy Sinatra': 1.0,
#  'Julie Webb': 1.0,
#  'David Marshall Grant': 0.45454545454545453,
#  'Dan Howard': 1.0,
#  'German Robles': 0.0,
#  'Cathy Tyson': 1.0,
#  'Patricia Clarckson': 1.0,
#  'Tommy Rall': 0.5333333333333333,
#  'Al Cliver': 1.0,
#  'Jeremy Folman': 1.0,
#  'Marge Champion': 0.4722222222222222,
#  'Carmen McRae': 1.0,
#  'William Royle': 1.0,
#  'William Campbell': 0.22849213691026826,
#  'Halle Berry': 0.2923076923076923,
#  'Kristin Scott Thomas': 0.22857142857142856,
#  'Ray Girardin': 1.0,
#  'Jeff Morrow': 0.38571428571428573,
#  'Noble Willingham': 1.0,
#  'Elliot Street': 1.0,
#  'Robert Romanus': 1.0,
#  'Ted White': 1.0,
#  'Jules Berry': 0.6666666666666666,
#  'Shuji Otaki': 1.0,
#  'Christy Thom': 1.0,
#  'L. Paul': 1.0,
#  'Ian MacShane': 1.0,
#  'Jeremy Sisto': 0.5151515151515151,
#  "L'Amante del Vampiro": 1.0,
#  'JeniferWardLeland': 1.0,
#  'Beatrice Ronand': 1.0,
#  'Cora Withersppon': 1.0,
#  'Lawrence Tierner': 1.0,
#  'Eric Pearce': 1.0,
#  'Claude Atkins': 0.696969696969697,
#  'Lisa Marie': 1.0,
#  'Carrie Fisher': 0.1168179646440516,
#  'George C. scott': 1.0,
#  'Niall MacGinnis': 0.3141025641025641,
#  'Jenny Robertson': 0.6727272727272727,
#  'Willie Aames': 0.0,
#  'Stephen d. Newman': 1.0,
#  'Maya Rojo': 1.0,
#  'Peter Brown': 0.3333333333333333,
#  'Lois Moran': 1.0,
#  'Lola Albright': 0.5277777777777778,
#  'Whitney Houston': 0.42943548387096775,
#  'Marjorie Weaver': 0.3333333333333333,
#  'Jeanne Eagels': 1.0,
#  'Pamela Light': 1.0,
#  'James Spader': 0.1524822695035461,
#  'Brenda Fricker': 0.19576719576719576,
#  'Janis Paige': 0.32429378531073444,
#  'Yale Benner': 1.0,
#  'Eddie Falco': 1.0,
#  'Leonie Flugrath': 1.0,
#  'Howard Caine': 0.24242424242424243,
#  'Valentina Cortese': 0.1808080808080808,
#  'Dennis Weaver': 0.38421052631578945,
#  'Vincent DOnofrio': 0.4,
#  'Yuri Borienko': 1.0,
#  'Linda Carpenter': 1.0,
#  'Shirley Eaton': 0.21176470588235294,
#  'Aleksandr Antonov': 1.0,
#  'Sir Guy Standing': 1.0,
#  'Andras Ambrus': 1.0,
#  'Ben Turpin': 0.4946236559139785,
#  'Evelyne Didi': 1.0,
#  'Busby Berkeley': 1.0,
#  'Milena Vukotic': 1.0,
#  'Wolfgang Kieling': 1.0,
#  'Karl Hardman': 1.0,
#  'Shelly Manne': 1.0,
#  'Angela Hall': 1.0,
#  'Melissa Sue Anderson': 1.0,
#  'Mairata Obsiedo': 1.0,
#  'Adreinne Dore': 1.0,
#  'Barry Miller': 0.5641025641025641,
#  'Robert Lowey': 1.0,
#  'J.M. Kerrigan': 1.0,
#  'Rutiger Hauer': 1.0,
#  'Basil Radford': 0.19305794606999427,
#  'Douglas Walton': 0.6,
#  'Michael Zaslow': 1.0,
#  'Bruce Jones': 1.0,
#  'Gary Sinise': 0.17718715393134,
#  'Trini Alvorado': 1.0,
#  'Paul Pincerni': 1.0,
#  'Anne Parillaud': 0.6111111111111112,
#  'Cindy Girling': 1.0,
#  'Richard Gladstein': 1.0,
#  'Lorna Luft': 0.4909090909090909,
#  'Karen Dotrice': 0.48484848484848486,
#  'John Calvin': 1.0,
#  'Tony Eppley': 1.0,
#  'Catherine Hicks': 0.4263157894736842,
#  'Alexei Lyarski': 1.0,
#  'Zachary Scott': 0.2658569500674764,
#  'Bella Lehczky': 1.0,
#  'Mischa Auer': 0.12453278967040435,
#  'Skeggs': 1.0,
#  'Barry Crocker': 1.0,
#  'Joan Gardner': 1.0,
#  'Paula Sheppard': 0.3333333333333333,
#  'Sharon D. Clarke': 1.0,
#  'Lisa Bonet': 1.0,
#  'Philippe Volter': 1.0,
#  'Louise Fletcher': 0.12704174228675136,
#  'Jack Riley': 0.5156695156695157,
#  'Carol Channing': 0.3736842105263158,
#  'Anders Randolph': 1.0,
#  'James Rebhorn Und': 1.0,
#  'Ma Jingwu': 1.0,
#  'Mary Beth Hurt': 0.1896551724137931,
#  'Douglas dumbrille': 1.0,
#  'Ross Sisters': 1.0,
#  'Robert Cochran': 1.0,
#  'Heiner Mulller': 1.0,
#  'Dorothy Malone': 0.119245413637937,
#  'Eleanor Bron': 0.2751322751322751,
#  'John Hall': 1.0,
#  'William Talman': 0.5238095238095238,
#  'Herman Brix': 0.4642857142857143,
#  'Gale Sondergard': 0.24225352112676057,
#  'Zahra Naderi': 1.0,
#  'Frankie Thomas': 0.3333333333333333,
#  ...}

# %%
grouped_communities = {}
for actor, key in communities.items():
    if key not in grouped_communities:
        grouped_communities[key] = set()

    grouped_communities[key].add(actor) # add actor

# %%
max_group = []
for key, group in grouped_communities.items():
    if len(group) > len(max_group):
        max_group = group

# %%
len(max_group)
# Out:
# 9982

# %%
kevin = 'Kevin Bacon'
dist = {}
sum_dist = 0
for actor in G:
    if nx.has_path(G, actor, kevin) and actor is not kevin:
        path = nx.shortest_path(G, actor, 'Kevin Bacon')
        dist[actor] = path
        sum_dist += len(path)

print(sum_dist / len(dist))
# Out:
# 4.1517881332972095

# %%
bacon_numbers = {}
# coputed demanding
for actor1 in G:
    counter = 0
    sum_dist = 0
    for actor2 in G:
        if nx.has_path(G, actor1, actor2) and actor1 is not actor2:
            path = nx.shortest_path(G, actor1, actor2)
            counter += 1
            sum_dist += len(path)
    if actor1 not in bacon_numbers:
        bacon_numbers[actor1] = (sum_dist / counter)

# %%
eigenvector = np.array(sorted(nx.eigenvector_centrality(G, max_iter=200).items(), key=operator.itemgetter(1), reverse=True))
eigenvector[:10]
# Out:
# array([['C.Aubrey Smith', '0.10528209757852323'],
#        ['John Carradine', '0.09890108262349977'],
#        ['James Stewart', '0.09305015308449284'],
#        ['Peter Lorre', '0.09255693271404085'],
#        ['John Gielgud', '0.09158287381618666'],
#        ['Basil Rathbone', '0.08982489646183787'],
#        ['Gary Cooper', '0.08939051353229847'],
#        ['David Niven', '0.08746568401219347'],
#        ['Andy Devine', '0.08729150852907477'],
#        ['Humphrey Bogart', '0.08503272445149634']],
#       dtype='<U37')

# %%
betweennes = np.array(sorted(nx.betweenness_centrality(G, k=200).items(), key=operator.itemgetter(1), reverse=True))
betweennes[:10]
# Out:
# array([['Humphrey Bogart', '0.017610208558268385'],
#        ['Gene Hackman', '0.01391599589094254'],
#        ['Burt Lancaster', '0.01322871167054944'],
#        ['Vincent Price', '0.011760001176388427'],
#        ['John Carradine', '0.011408244471061216'],
#        ['Keenan Wynn', '0.011363517694990641'],
#        ['James Stewart', '0.01099101157989122'],
#        ['Robert deNiro', '0.010317115956787484'],
#        ['David Niven', '0.010137944793591806'],
#        ['Donald Sutherland', '0.008847459344095839']],
#       dtype='<U37')

# %%
nx.write_gexf(G, "export.gexf")
